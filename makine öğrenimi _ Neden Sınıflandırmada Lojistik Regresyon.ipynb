# %% [markdown]
# Bir postayı spam veya spam değil olarak sınıflandırdığımızı ve çıktımızın y olduğunu, 0(spam) veya 1(spam değil) olabileceğini varsayalım. Doğrusal Regresyon durumunda, h θ (x) > 1 veya < 0 olabilir. Tahminimiz 0 ile 1 arasında olmasına rağmen, model aralığın dışındaki değeri tahmin edecektir, yani belki > 1 veya < 0.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Bir örnekle Karar Sınırını Anlamak

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
