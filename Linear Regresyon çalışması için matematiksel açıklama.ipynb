# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Doğrusal regresyon hipotezi ile yineleme 1'den sonra tahmin edilen değerler.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Verilen, bir şirketin İş vs Deneyim veri setidir ve görev, bir çalışanın iş tecrübesine dayalı olarak maaşını tahmin etmektir. Bu makale, tahmin görevini gerçekleştirmek için önceden tanımlanmış bir fonksiyon kullandığımızda  Lineer regresyonun
# gerçekte matematiksel olarak nasıl çalıştığını açıklamayı amaçlamaktadır . Doğrusal Regresyon algoritması eğitildiğinde öğelerin nasıl çalıştığını  keşfedelim .

# %% [markdown]
# Yineleme 1 – Başlangıçta θ 0 ve θ 1 değerleri rastgele seçilir. Diyelim ki θ 0 = 0 ve θ 1 = 0.

# %% [markdown]
# Maliyet Fonksiyonu – Hata
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gradient Descent – ​​Güncelleniyor θ 0 değeri
# Burada, j = 0
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Gradient Descent – ​​Güncelleme θ 1 değeri
# Burada, j = 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Yineleme 2 – θ 0 = 0,005 ve θ 1 = 0,02657

# %% [markdown]
# Doğrusal regresyon hipotezi ile yineleme 1'den sonra tahmin edilen değerler.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Şimdi, yineleme no'ya benzer. Yukarıda gerçekleştirdiğimiz 1'de tekrar Maliyet fonksiyonunu hesaplayacağız ve Gradient Descent kullanarak θ j değerlerini güncelleyeceğiz. Maliyet işlevi daha fazla azalmayana kadar yinelemeye devam edeceğiz. Bu noktada model en iyi θ değerlerine ulaşır. Bu θ değerlerinin model hipotezinde kullanılması en iyi tahmin sonuçlarını verecektir.
