# %% [markdown]
# #Sklearn
# Python'un Sklearn kitaplığı, kendi özel veri kümenizi oluşturmanıza yardımcı olacak harika bir örnek veri kümesi oluşturucusu sağlar.
#
#  Hızlı ve kullanımı çok kolaydır.
#  Sağladığı örnek türleri aşağıdadır.

# %% [markdown]
# ##Kurulması Gereken Kütüphaneler

# %%
from  sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.datasets import make_circles
from matplotlib import pyplot as plt
from matplotlib import style

# %% [markdown]
# ##Sklearn Leke Kümesi

# %%
style.use("fivethirtyeight")
X,y = make_blobs(n_samples = 100, centers = 3,
                 cluster_std = 1, n_features = 2 )

plt.scatter(X[:,0],X[:,1], s = 30, color = "r")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
plt.clf()

# %% [markdown]
# ##Sklearn Hilal Kümesi

# %%
X,y = make_moons(n_samples = 1000, noise = 0.1)

plt.scatter(X[:,0], X[:,1], s=100, color = "g")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
plt.clf()

# %% [markdown]
# ##Sklearn Daire Kümesi

# %%
style.use("fivethirtyeight")

X,y = make_circles(n_samples = 100, noise = 0.02)

plt.scatter(X[:,0],X[:,1], s = 40, color = "r")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
plt.clf()
