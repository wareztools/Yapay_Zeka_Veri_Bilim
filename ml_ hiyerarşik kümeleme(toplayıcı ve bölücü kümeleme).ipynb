# %% [markdown]
# 1. Aglomeratif Kümeleme: Aşağıdan yukarıya yaklaşım veya hiyerarşik aglomeratif kümeleme (HAC) olarak da bilinir. Düz kümeleme tarafından döndürülen yapılandırılmamış kümeler kümesinden daha bilgilendirici bir yapı. Bu kümeleme algoritması, küme sayısını önceden belirlememizi gerektirmez. Aşağıdan yukarıya algoritmalar, başlangıçta her veriyi tek bir küme olarak ele alır ve ardından tüm kümeler, tüm verileri içeren tek bir kümede birleştirilene kadar küme çiftlerini art arda kümeler.

# %% [markdown]
# ```
# given a dataset (d1, d2, d3, ....dN) of size N
# # compute the distance matrix
# for i=1 to N:
#    # as the distance matrix is symmetric about
#    # the primary diagonal so we compute only lower
#    # part of the primary diagonal
#    for j=1 to i:
#       dis_mat[i][j] = distance[di, dj]
# each data point is a singleton cluster
# repeat
#    merge the two cluster having minimum distance
#    update the distance matrix
# until only a single cluster remains
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

X = np.array([[1,2],[1,4],[1,0],
             [4,2],[4,4],[4,0]])
clustering = AgglomerativeClustering(n_clusters = 2).fit(X)

print(clustering.labels_)
# Out:
# [1 1 1 0 0 0]

# %% [markdown]
# 2. Bölücü kümeleme: Yukarıdan aşağıya yaklaşım olarak da bilinir. Bu algoritma ayrıca küme sayısını önceden belirtmeyi gerektirmez. Yukarıdan aşağıya kümeleme, tüm verileri içeren bir kümeyi bölmek için bir yöntem gerektirir ve bireysel veriler tekil kümelere bölünene kadar kümeleri yinelemeli olarak bölerek ilerler.
